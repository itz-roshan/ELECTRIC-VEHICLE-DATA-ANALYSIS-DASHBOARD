# %% [markdown]
# # ⚡ Electric Vehicle Population Data
#
# > **Dataset:** Electric Vehicle Population Data (Washington State, USA)
# > **Total Records:** 1,50,487 | **Features:** 17
# > **Goal:** Understand EV adoption trends, market share, range distribution, and geographic spread.
#
# ---

# %%
import pandas as pd

# %%
df = pd.read_csv("Electric_Vehicle_Population_Data_RAW.csv")
df.head()
# Out:
#    VIN (1-10)    County      City State  Postal Code  Model Year     Make  \
# 0  KM8K33AGXL      King   Seattle    WA      98103.0        2020  HYUNDAI
# 1  1C4RJYB61N      King   Bothell    WA      98011.0        2022     JEEP
# 2  1C4RJYD61P    Yakima    Yakima    WA      98908.0        2023     JEEP
# 3  5YJ3E1EA7J      King  Kirkland    WA      98034.0        2018    TESLA
# 4  WBY7Z8C5XJ  Thurston   Olympia    WA      98501.0        2018      BMW
#
#             Model                   Electric Vehicle Type  \
# 0            KONA          Battery Electric Vehicle (BEV)
# 1  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 3         MODEL 3          Battery Electric Vehicle (BEV)
# 4              I3  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             258
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150494 entries, 0 to 150493
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         150494 non-null  str
#  1   County                                             150491 non-null  str
#  2   City                                               150491 non-null  str
#  3   State                                              150494 non-null  str
#  4   Postal Code                                        150491 non-null  float64
#  5   Model Year                                         150494 non-null  int64
#  6   Make                                               150494 non-null  str
#  7   Model                                              150494 non-null  str
#  8   Electric Vehicle Type                              150494 non-null  str
# ...

# %%
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  150491.000000  150494.000000   150494.000000  150494.000000
# mean    98168.343476    2020.005548       67.874613    1312.540068
# std      2473.514359       3.015167       96.227649    9230.949606
# min      1730.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2018.000000        0.000000       0.000000
# 50%     98122.000000    2021.000000       18.000000       0.000000
# 75%     98370.000000    2023.000000       97.000000       0.000000
# max     99577.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         150153.000000    1.504940e+05       1.504910e+05
# mean              29.344648    2.111116e+08       5.297196e+10
# std               14.824850    8.196162e+07       1.638776e+09
# min                1.000000    4.385000e+03       1.081042e+09
# ...

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 341
# DOL Vehicle ID                                         0
# Vehicle Location                                       7
# Electric Utility                                       3
# ...

# %%
df.dtypes
# Out:
# VIN (1-10)                                               str
# County                                                   str
# City                                                     str
# State                                                    str
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                     str
# Model                                                    str
# Electric Vehicle Type                                    str
# Clean Alternative Fuel Vehicle (CAFV) Eligibility        str
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                         str
# ...

# %%
df.isnull().sum()/(len(df)*100) # used to check percentange
# Out:
# VIN (1-10)                                           0.000000e+00
# County                                               1.993435e-07
# City                                                 1.993435e-07
# State                                                0.000000e+00
# Postal Code                                          1.993435e-07
# Model Year                                           0.000000e+00
# Make                                                 0.000000e+00
# Model                                                0.000000e+00
# Electric Vehicle Type                                0.000000e+00
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0.000000e+00
# Electric Range                                       0.000000e+00
# Base MSRP                                            0.000000e+00
# Legislative District                                 2.265871e-05
# DOL Vehicle ID                                       0.000000e+00
# ...

# %%
df.dropna().shape
# Out:
# (150149, 17)

# %%
df['Legislative District']=df['Legislative District'].fillna(df['Legislative District'].mode().iloc[0])

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 150487 entries, 0 to 150493
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         150487 non-null  str
#  1   County                                             150487 non-null  str
#  2   City                                               150487 non-null  str
#  3   State                                              150487 non-null  str
#  4   Postal Code                                        150487 non-null  float64
#  5   Model Year                                         150487 non-null  int64
#  6   Make                                               150487 non-null  str
#  7   Model                                              150487 non-null  str
#  8   Electric Vehicle Type                              150487 non-null  str
# ...

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %%
col=df.columns
for i in col:
    print(i)
    print(df[i].unique())
# Out:
# VIN (1-10)
# <StringArray>
# ['KM8K33AGXL', '1C4RJYB61N', '1C4RJYD61P', '5YJ3E1EA7J', 'WBY7Z8C5XJ',
#  '5YJ3E1EAXL', '2C4RC1N77H', '5YJYGDEE3L', '5YJ3E1EA1J', '7SAYGDEF0P',
#  ...
#  '7JRBR0FZ7M', '4JGDA6DBXH', '1FTZR081XY', '50EA1DCA2N', 'WB533CF03R',
#  '1FMCU0EZ8M', '7FCTGAAL0P', 'WA1CAAGE9R', 'WA1G2BFZ5N', 'JN1CF0BB5P']
# Length: 9528, dtype: str
# County
# <StringArray>
# [       'King',      'Yakima',    'Thurston',   'Snohomish',      'Island',
#       'Kitsap',     'Whitman',      'Skagit',    'Kittitas', 'Walla Walla',
#  ...
#     'Kootenai',  'Williamson',       'Sarpy',  'Las Animas',   'St. Clair',
#     'Hennepin',        'Maui',        'Bell',  'Portsmouth',     'Suffolk']
# Length: 183, dtype: str
# City
# <StringArray>
# [      'Seattle',       'Bothell',        'Yakima',      'Kirkland',
#        'Olympia',    'Marysville',          'Kent',   'Woodinville',
#     'Coupeville',      'Bellevue',
#  ...
# ...

# %%
df[df.duplicated()].shape
# Out:
# (12, 17)

# %%
df=df.drop_duplicates()

# %%
df[df.duplicated()].shape
# Out:
# (0, 17)

# %%
df['State'].unique()
# Out:
# <StringArray>
# ['WA', 'CA', 'IL', 'NE', 'MO', 'AZ', 'VA', 'KY', 'NC', 'MD', 'DC', 'WY', 'GA',
#  'OR', 'FL', 'MS', 'TX', 'AL', 'HI', 'CO', 'CT', 'LA', 'MT', 'NV', 'NY', 'NJ',
#  'OH', 'DE', 'PA', 'IN', 'NH', 'AR', 'ID', 'UT', 'SC', 'KS', 'AK', 'MA', 'MN']
# Length: 39, dtype: str

# %%
df.to_csv('Clean_EV_USA_WA_data.csv')
